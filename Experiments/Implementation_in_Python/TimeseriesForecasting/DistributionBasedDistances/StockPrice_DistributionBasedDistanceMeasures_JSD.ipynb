# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import plotly.graph_objects as go
import plotly.express as px

# %%
filepath = "RELIANCE_2010-01-012021-08-30.csv"
data = pd.read_csv(filepath, usecols=[0,4], names=['date', 'close'], header=0)
data = data.sort_values('date')
data['date'] = pd.to_datetime(data['date'])
data.head()
# Out:
#         date    close
# 0 2010-01-04  1075.50
# 1 2010-01-05  1070.70
# 2 2010-01-06  1088.00
# 3 2010-01-07  1106.05
# 4 2010-01-08  1103.15

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=data['date'], y=data['close'], mode='lines', name='closing price'))

fig.update_xaxes(range=["2009-11-01", "2021-11-01"])
fig.update_yaxes(range=[500, 2500])
# Out:
# <div>                            <div id="37153d8b-4422-431c-8856-eb75dcd8add9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37153d8b-4422-431c-8856-eb75dcd8add9")) {                    Plotly.newPlot(                        "37153d8b-4422-431c-8856-eb75dcd8add9",                        [{"mode":"lines","name":"closing price","x":["2010-01-04T00:00:00","2010-01-05T00:00:00","2010-01-06T00:00:00","2010-01-07T00:00:00","2010-01-08T00:00:00","2010-01-11T00:00:00","2010-01-12T00:00:00","2010-01-13T00:00:00","2010-01-14T00:00:00","2010-01-15T00:00:00","2010-01-18T00:00:00","2010-01-19T00:00:00","2010-01-20T00:00:00","2010-01-21T00:00:00","2010-01-22T00:00:00","2010-01-25T00:00:00","2010-01-27T00:00:00","2010-01-28T00:00:00","2010-01-29T00:00:00","2010-02-01T00:00:00","2010-02-02T00:00:00","2010-02-03T00:00:00","2010-02-04T00:00:00","2010-02-05T00:00:00","2010-02-06T00:00:00","2010-02-08T00:00:00","2010-02-09T00:00:00","2010-02-10T00:00:00","2010-02-11T00:00:00","2010-02-15T00:00:00","2010-02-16T00:00:00","2010-02-17T00:00:00","2010-02-18T00:00:00","2010-02-19T00:00:00","2010-02-22T00:00:00","2010-02-23T00:00:00","2010-02-24T00:00:00","2010-02-25T00:00:00","2010-02-26T00:00:00","2010-03-02T00:00:00","2010-03-03T00:00:00","2010-03-04T00:00:00","2010-03-05T00:00:00","2010-03-08T00:00:00","2010-03-09T00:00:00","2010-03-10T00:00:00","2010-03-11T00:00:00","2010-03-12T00:00:00","2010-03-15T00:00:00","2010-03-16T00:00:00","2010-03-17T00:00:00","2010-03-18T00:00:00","2010-03-19T00:00:00","2010-03-22T00:00:00","2010-03-23T00:00:00","2010-03-25T00:00:00","2010-03-26T00:00:00","2010-03-29T00:00:00","2010-03-30T00:00:00","2010-03-31T00:00:00","2010-04-01T00:00:00","2010-04-05T00:00:00","2010-04-06T00:00:00","2010-04-07T00:00:00","2010-04-08T00:00:00","2010-04-09T00:00:00","2010-04-12T00:00:00","2010-04-13T00:00:00","2010-04-15T00:00:00","2010-04-16T00:00:00","2010-04-19T00:00:00","2010-04-20T00:00:00","2010-04-21T00:00:00","2010-04-22T00:00:00","2010-04-23T00:00:00","2010-04-26T00:00:00","2010-04-27T00:00:00","2010-04-28T00:00:00","2010-04-29T00:00:00","2010-04-30T00:00:00","2010-05-03T00:00:00","2010-05-04T00:00:00","2010-05-05T00:00:00","2010-05-06T00:00:00","2010-05-07T00:00:00","2010-05-10T00:00:00","2010-05-11T00:00:00","2010-05-12T00:00:00","2010-05-13T00:00:00","2010-05-14T00:00:00","2010-05-17T00:00:00","2010-05-18T00:00:00","2010-05-19T00:00:00","2010-05-20T00:00:00","2010-05-21T00:00:00","2010-05-24T00:00:00","2010-05-25T00:00:00","2010-05-26T00:00:00","2010-05-27T00:00:00","2010-05-28T00:00:00","2010-05-31T00:00:00","2010-06-01T00:00:00","2010-06-02T00:00:00","2010-06-03T00:00:00","2010-06-04T00:00:00","2010-06-07T00:00:00","2010-06-08T00:00:00","2010-06-09T00:00:00","2010-06-10T00:00:00","2010-06-11T00:00:00","2010-06-14T00:00:00","2010-06-15T00:00:00","2010-06-16T00:00:00","2010-06-17T00:00:00","2010-06-18T00:00:00","2010-06-21T00:00:00","2010-06-22T00:00:00","2010-06-23T00:00:00","2010-06-24T00:00:00","2010-06-25T00:00:00","2010-06-28T00:00:00","2010-06-29T00:00:00","2010-06-30T00:00:00","2010-07-01T00:00:00","2010-07-02T00:00:00","2010-07-05T00:00:00","2010-07-06T00:00:00","2010-07-07T00:00:00","2010-07-08T00:00:00","2010-07-09T00:00:00","2010-07-12T00:00:00","2010-07-13T00:00:00","2010-07-14T00:00:00","2010-07-15T00:00:00","2010-07-16T00:00:00","2010-07-19T00:00:00","2010-07-20T00:00:00","2010-07-21T00:00:00","2010-07-22T00:00:00","2010-07-23T00:00:00","2010-07-26T00:00:00","2010-07-27T00:00:00","2010-07-28T00:00:00","2010-07-29T00:00:00","2010-07-30T00:00:00","2010-08-02T00:00:00","2010-08-03T00:00:00","2010-08-04T00:00:00","2010-08-05T00:00:00","2010-08-06T00:00:00","2010-08-09T00:00:00","2010-08-10T00:00:00","2010-08-11T00:00:00","2010-08-12T00:00:00","2010-08-13T00:00:00","2010-08-16T00: ...

# %%
def splitData(ts):

    test_set_size = int(np.round(0.2*len(ts)));
    train_set = ts[:-test_set_size]    
    test_set = ts[-test_set_size:]

    return train_set, test_set

# %%
def modify_test_data(test_set, mean, variance):
    
    noise = np.random.normal(mean, variance, len(test_set))
    # print("noise", noise[:50])
    modified_test_Set = test_set + noise

    return modified_test_Set

# %%
train_set, test_set = splitData(data['close'].values)

# %%
X1, X2 = train_set, test_set
mean1, mean2 = X1.mean(), X2.mean()
var1, var2 = X1.var(), X2.var()
print('mean1=%f, mean2=%f' % (mean1, mean2))
print('variance1=%f, variance2=%f' % (var1, var2))
# Out:
# mean1=973.087522, mean2=1718.089983
# variance1=28266.246848, variance2=136205.599459

# %% [markdown]
# ### Compute KL-Divergence and Jensen-Shannon Divergence

# %% [markdown]
# #### 1. KL Divergence

# %%
def KLD(P,Q,delta_x=1):
    print("P", P)
    print("Q", Q)
    # print( P*np.log(P/Q))
    return np.sum(P* np.log(P/Q))
    # return np.sum( P * np.log( P/Q ) ) * delta_x

# %%
def sample_KLD(bins=10):
    values_1, edges_1 = np.histogram(X1,bins=bins,density=True)
    values_2, edges_2 = np.histogram(X2,bins=bins,density=True)
    
    #Consider only first std. deviation of original series i.e. P(x).
    # return KLD(0.68*values_1,values_2, 2/bins)
    return KLD(0.68*values_1,values_2)

# %%
x0 = X1
# Add 1 to shift the mean of the Gaussian distribution
x1 = X2

df =pd.DataFrame(dict(
    series=np.concatenate((["a"]*len(x0), ["b"]*len(x1))), 
    data  =np.concatenate((x0,x1))
))

px.histogram(df, x="data", color="series", barmode="overlay", nbins=10, histnorm='probability density')
# px.histogram(df, x="data", color="series", barmode="overlay")
# Out:
# <div>                            <div id="c8cabf54-849c-482c-8f7d-2a6e91523f6a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c8cabf54-849c-482c-8f7d-2a6e91523f6a")) {                    Plotly.newPlot(                        "c8cabf54-849c-482c-8f7d-2a6e91523f6a",                        [{"alignmentgroup":"True","bingroup":"x","histnorm":"probability density","hovertemplate":"series=a<br>data=%{x}<br>probability density=%{y}<extra></extra>","legendgroup":"a","marker":{"color":"#636efa","opacity":0.5,"pattern":{"shape":""}},"name":"a","nbinsx":10,"offsetgroup":"a","orientation":"v","showlegend":true,"x":[1075.5,1070.7,1088.0,1106.05,1103.15,1081.5,1084.35,1088.6,1121.7,1110.75,1099.5,1085.0,1077.5,1054.05,1053.85,1042.05,1027.55,1037.15,1046.2,1045.4,1027.3,1033.95,1019.15,981.7,993.75,994.35,993.25,985.1,1015.15,1010.0,1017.75,1032.55,997.8,983.2,977.95,975.35,978.8,963.1,978.95,983.2,1024.8,1014.0,1009.8,1004.1,990.35,1008.75,1016.45,1021.6,1028.05,1067.95,1069.7,1076.95,1092.05,1073.95,1091.4,1091.45,1100.45,1093.3,1088.15,1074.25,1092.05,1125.9,1123.2,1129.7,1106.55,1124.7,1127.35,1120.9,1090.7,1084.25,1061.8,1063.2,1054.1,1075.75,1088.2,1071.25,1061.25,1017.25,1035.05,1033.6,1023.75,1021.15,1020.65,1007.85,1032.8,1079.4,1067.8,1082.95,1071.8,1043.65,1016.55,1020.6,998.65,999.95,995.55,1022.65,985.65,1008.05,1022.25,1036.65,1045.6,1010.55,1011.05,1030.8,1031.2,1007.75,996.4,1007.05,1015.35,1046.4,1063.5,1066.1,1057.95,1071.4,1054.35,1065.65,1063.8,1058.7,1052.05,1062.95,1090.15,1067.45,1089.85,1076.25,1068.95,1068.3,1073.9,1053.55,1057.1,1057.65,1056.25,1074.3,1070.45,1073.45,1062.95,1056.05,1052.95,1058.4,1059.0,1060.45,1053.1
# %%
X1, X2 = train_set, test_set[:50]
mean1, mean2 = X1.mean(), X2.mean()
var1, var2 = X1.var(), X2.var()
print('mean1=%f, mean2=%f' % (mean1, mean2))
print('variance1=%f, variance2=%f' % (var1, var2))
# Out:
# mean1=973.087522, mean2=1305.453000
# variance1=28266.246848, variance2=1714.464541

# %%
x0 = X1
# Add 1 to shift the mean of the Gaussian distribution
x1 = X2

df =pd.DataFrame(dict(
    series=np.concatenate((["a"]*len(x0), ["b"]*len(x1))), 
    data  =np.concatenate((x0,x1))
))

px.histogram(df, x="data", color="series", barmode="overlay", nbins=10, histnorm='probability density')
# px.histogram(df, x="data", color="series", barmode="overlay")
# Out:
# <div>                            <div id="03df0bb1-5c20-4f91-98f8-3e5b06739b15" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("03df0bb1-5c20-4f91-98f8-3e5b06739b15")) {                    Plotly.newPlot(                        "03df0bb1-5c20-4f91-98f8-3e5b06739b15",                        [{"alignmentgroup":"True","bingroup":"x","histnorm":"probability density","hovertemplate":"series=a<br>data=%{x}<br>probability density=%{y}<extra></extra>","legendgroup":"a","marker":{"color":"#636efa","opacity":0.5,"pattern":{"shape":""}},"name":"a","nbinsx":10,"offsetgroup":"a","orientation":"v","showlegend":true,"x":[1075.5,1070.7,1088.0,1106.05,1103.15,1081.5,1084.35,1088.6,1121.7,1110.75,1099.5,1085.0,1077.5,1054.05,1053.85,1042.05,1027.55,1037.15,1046.2,1045.4,1027.3,1033.95,1019.15,981.7,993.75,994.35,993.25,985.1,1015.15,1010.0,1017.75,1032.55,997.8,983.2,977.95,975.35,978.8,963.1,978.95,983.2,1024.8,1014.0,1009.8,1004.1,990.35,1008.75,1016.45,1021.6,1028.05,1067.95,1069.7,1076.95,1092.05,1073.95,1091.4,1091.45,1100.45,1093.3,1088.15,1074.25,1092.05,1125.9,1123.2,1129.7,1106.55,1124.7,1127.35,1120.9,1090.7,1084.25,1061.8,1063.2,1054.1,1075.75,1088.2,1071.25,1061.25,1017.25,1035.05,1033.6,1023.75,1021.15,1020.65,1007.85,1032.8,1079.4,1067.8,1082.95,1071.8,1043.65,1016.55,1020.6,998.65,999.95,995.55,1022.65,985.65,1008.05,1022.25,1036.65,1045.6,1010.55,1011.05,1030.8,1031.2,1007.75,996.4,1007.05,1015.35,1046.4,1063.5,1066.1,1057.95,1071.4,1054.35,1065.65,1063.8,1058.7,1052.05,1062.95,1090.15,1067.45,1089.85,1076.25,1068.95,1068.3,1073.9,1053.55,1057.1,1057.65,1056.25,1074.3,1070.45,1073.45,1062.95,1056.05,1052.95,1058.4,1059.0,1060.45,1053.1,1053.5,1021.25,1010.15,1009.65,1014.55,1027.75,1016.05,1007.05,1000.1,993.6,987.9,983.25,972.6,979.1,976.9,970.65,964.6,977.2,988.65,976.9,972.4,967.8,956.45,949.6,947.95,919.2,936.2,937.45,925.7,952.65,962.3,959.6,958.55,992.5,988.15,1013.9,1000.35,1027.35,1041.4,1035.15,1020.05,997.65,1001.65,1010.2,998.5,999.0,987.25,1007.9,1017.85,1023.85,1044.95,1039.15,1049.65,1069.2,1055.6,1073.05,1059.0,1040.35,1047.45,1044.4,1049.45,1081.65,1081.8,1090.35,1098.85,1092.75,1082.0,1096.25,1093.2,1074.85,1065.3,1105.05,1105.7,1111.85,1108.55,1102.2,1079.9,1061.85,1054.7,1030.5,1032.95,996.25,1012.25,995.6,996.05,979.5,962.35,998.4,985.6,988.8,1011.15,1005.9,1020.15,1030.75,1020.55,984.5,1023.9,1041.75,1055.25,1053.9,1056.85,1056.75,1073.15,1056.05,1059.4,1059.7,1055.25,1047.9,1048.6,1051.2,1058.7,1055.6,1077.1,1075.8,1085.6,1065.4,1033.45,1013.75,1030.8,1015.35,1001.5,997.9,994.85,980.15,969.85,986.8,971.6,958.5,942.7,913.0,919.3,895.5,921.3,943.9,920.0,929.05,915.25,914.3,899.65,909.95,914.8,941.7,944.15,953.95,935.55,956.35,984.85,995.65,964.2,966.25,964.25,988.85,977.4,982.2,977.05,984.95,993.85,984.75,992.05,1018.35,1037.25,1047.1,1030.85,993.0,990.3,999.65,1013.25,1010.3,1026.6,1025.7,1022.75,1032.5,1049.1,1036.4,1050.65,1047.65,1044.85,1041.9,1023.9,1005.3,1021.8,1020.95,1009.15,1011.65,1025.9,1040.6,1009.35,1001.15,986.1,972.4,983.75,964.75,943.9,947.65,949.95,955.05,955.05,959.3,950.75,955.45,945.5,948.0,945.0,920.65,901.85,915.5,923.2,909.4,915.75,906.0,933.85,945.45,938.85,951.85,946.8,951.05,934.6,937.75,958.25,949.2,954.0,944.5,925.6,911.35,900.55,887.55,868.75,833.25,848.65,845.8,870.5,871.4,871.55,871.1,885.25,898.5,861.95,868.4,845.95,852.9,870.7,854.85,853.3,847.75,865.45,867.55,873.2,867.6,879.45,876.2,860.85,873.35,882.85,871.5,860.85,837.35,827.95,830.85,837.3,825.05,812.35,792.0,780.65,765.3,765.3,772.75,772.2,760.9,759.15,755.0,741.2,732.55,757.0,765.25,761.3,753.5,719.4,755.05,782.6,805.45,788.85,821.5,833.5,852.45,825.75,806.3,810.25,825.4,836.3,825.65,821.55,851.8,837.6,786.35,770.6,759.2,797.2,797.2,807.7,808.35,788.2,771.6,767.0,802.9,829.25,827.0,8 ...

# %%
print(' KLD = %+8.2e' % (sample_KLD(bins=10)))
# Out:
# P [4.91359102e-04 1.51627993e-03 1.73633646e-03 1.86595880e-03
#  6.33039334e-04 2.26085476e-04 2.32114422e-04 1.53738124e-04
#  3.61736762e-05 9.04341905e-05]
# Q [0.00113122 0.01131222 0.01244344 0.00452489 0.00565611 0.01131222
#  0.00452489 0.00113122 0.00113122 0.00339367]
#  KLD = -1.22e-02

# %%
X1, X2 = train_set, test_set[50:100]
mean1, mean2 = X1.mean(), X2.mean()
var1, var2 = X1.var(), X2.var()
print('mean1=%f, mean2=%f' % (mean1, mean2))
print('variance1=%f, variance2=%f' % (var1, var2))
# Out:
# mean1=973.087522, mean2=1231.705000
# variance1=28266.246848, variance2=2170.801025

# %%
x0 = X1
# Add 1 to shift the mean of the Gaussian distribution
x1 = X2

df =pd.DataFrame(dict(
    series=np.concatenate((["a"]*len(x0), ["b"]*len(x1))), 
    data  =np.concatenate((x0,x1))
))

px.histogram(df, x="data", color="series", barmode="overlay", nbins=10, histnorm='probability density')
# px.histogram(df, x="data", color="series", barmode="overlay")
# Out:
# <div>                            <div id="f21a956f-2725-42e4-98c3-0e00dca197ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f21a956f-2725-42e4-98c3-0e00dca197ce")) {                    Plotly.newPlot(                        "f21a956f-2725-42e4-98c3-0e00dca197ce",                        [{"alignmentgroup":"True","bingroup":"x","histnorm":"probability density","hovertemplate":
9,1005.3,1021.8,1020.95,1009.15,1011.65,1025.9,1040.6,1009.35,1001.15,986.1,972.4,983.75,964.75,943.9,947.65,949.95,955.05,955.05,959.3,950.75,955.45,945.5,948.0,945.0,920.65,901.85,915.5,923.2,909.4,915.75,906.0,933.85,945.45,938.85,951.85,946.8,951.05,934.6,937.75,958.25,949.2,954.0,944.5,925.6,911.35,900.55,887.55,868.75,833.25,848.65,845.8,870.5,871.4,871.55,871.1,885.25,898.5,861.95,868.4,845.95,852.9,870.7,854.85,853.3,847.75,865.45,867.55,873.2,867.6,879.45,876.2,860.85,873.35,882.85,871.5,860.85,837.35,827.95,830.85,837.3,825.05,812.35,792.0,780.65,765.3,765.3,772.75,772.2,760.9,759.15,755.0,741.2,732.55,757.0,765.25,761.3,753.5,719.4,755.05,782.6,805.45,788.85,821.5,833.5,852.45,825.75,806.3,810.25,825.4,836.3,825.65,821.55,851.8,837.6,786.35,770.6,759.2,797.2,797.2,807.7,808.35,788.2,771.6,767.0,802.9,829.25,827.0,8 ...

# %%
print(' KLD = %+8.2e' % (sample_KLD(bins=10)))
# Out:
# P [4.91359102e-04 1.51627993e-03 1.73633646e-03 1.86595880e-03
#  6.33039334e-04 2.26085476e-04 2.32114422e-04 1.53738124e-04
#  3.61736762e-05 9.04341905e-05]
# Q [0.00108932 0.00217865 0.00217865 0.0043573  0.0043573  0.00653595
#  0.00544662 0.00653595 0.00653595 0.01525054]
#  KLD = -6.86e-03

# %%
X1, X2 = train_set, test_set[100:200]
mean1, mean2 = X1.mean(), X2.mean()
var1, var2 = X1.var(), X2.var()
print('mean1=%f, mean2=%f' % (mean1, mean2))
print('variance1=%f, variance2=%f' % (var1, var2))
# Out:
# mean1=973.087522, mean2=1479.247000
# variance1=28266.246848, variance2=6690.764491

# %%
x0 = X1
# Add 1 to shift the mean of the Gaussian distribution
x1 = X2

df =pd.DataFrame(dict(
    series=np.concatenate((["a"]*len(x0), ["b"]*len(x1))), 
    data  =np.concatenate((x0,x1))
))

px.histogram(df, x="data", color="series", barmode="overlay", nbins=10, histnorm='probability density')
# px.histogram(df, x="data", color="series", barmode="overlay")
# Out:
# <div>                            <div id="8cd1801b-3717-4060-97e0-0e036369485c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8cd1801b-3717-4060-97e0-0e036369485c")) {                    Plotly.newPlot(                        "8cd1801b-3717-4060-97e0-0e036369485c",                        [{"alignmentgroup":"True","bingroup":"x","histnorm":"probability density","hovertemplate":"series=a<br>data=%{x}<br>probability density=%{y}<extra></extra>","legendgroup":"a","marker":{"color":"#636efa","opacity":0.5,"pattern":{"shape":""}},"name":"a","nbinsx":10,"offsetgroup":"a","orientation":"v","showlegend":true,"x":[1075.5,1070.7,1088.0,1106.05,1103.15,1081.5,1084.35,1088.6,1121.7,1110.75,1099.5,1085.0,1077.5,1054.05,1053.85,1042.05,1027.55,1037.15,1046.2,1045.4,1027.3,1033.95,1019.15,981.7,993.75,994.35,993.25,985.1,1015.15,1010.0,1017.75,1032.55,997.8,983.2,977.95,975.35,978.8,963.1,978.95,983.2,1024.8,1014.0,1009.8,1004.1,990.35,1008.75,1016.45,1021.6,1028.05,1067.95,1069.7,1076.95,1092.05,1073.95,1091.4,1091.45,1100.45,1093.3,1088.15,1074.25,1092.05,1125.9,1123.2,1129.7,1106.55,1124.7,1127.35,1120.9,1090.7,1084.25,1061.8,
# %%
print(' KLD = %+8.2e' % (sample_KLD(bins=10)))
# Out:
# P [4.91359102e-04 1.51627993e-03 1.73633646e-03 1.86595880e-03
#  6.33039334e-04 2.26085476e-04 2.32114422e-04 1.53738124e-04
#  3.61736762e-05 9.04341905e-05]
# Q [0.00211864 0.00060533 0.00151332 0.00151332 0.0033293  0.00514528
#  0.00242131 0.00514528 0.00635593 0.00211864]
#  KLD = -2.01e-03

# %%
X1, X2 = train_set, test_set[200:300]
mean1, mean2 = X1.mean(), X2.mean()
var1, var2 = X1.var(), X2.var()
print('mean1=%f, mean2=%f' % (mean1, mean2))
print('variance1=%f, variance2=%f' % (var1, var2))
# Out:
# mean1=973.087522, mean2=1431.919500
# variance1=28266.246848, variance2=65014.567495

# %%
x0 = X1
# Add 1 to shift the mean of the Gaussian distribution
x1 = X2

df =pd.DataFrame(dict(
    series=np.concatenate((["a"]*len(x0), ["b"]*len(x1))), 
    data  =np.concatenate((x0,x1))
))

px.histogram(df, x="data", color="series", barmode="overlay", nbins=10, histnorm='probability density')
# px.histogram(df, x="data", color="series", barmode="overlay")
# Out:
# <div>                            <div id="e73a68ae-db24-4b5d-8ad9-abeaef65bbd1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e73a68ae-db24-4b5d-8ad9-abeaef65bbd1")) {                    Plotly.newPlot(                        "e73a68ae-db24-4b5d-8ad9-abeaef65bbd1",                        [{"alignmentgroup":"True","bingroup":"x","histnorm":"probability density","hovertemplate":"series=a<br>data=%{x}<br>probability density=%{y}<extra></extra>","legendgroup":"a","marker":{"color":"#636efa","opacity":0.5,"pattern":{"shape":""}},"name":"a","nbinsx":10,"offsetgroup":"a","orientation":"v","showlegend":true,"x":[1075.5,1070.7,1088.0,1106.05,1103.15,1081.5,1084.35,1088.6,1121.7,1110.75,1099.5,1085.0,1077.5,1054.05,1053.85,1042.05,1027.55,1037.15,1046.2,1045.4,1027.3,1033.95,1019.15,981.7,993.75,994.35,993.25,985.1,1015.15,1010.0,1017.75,1032.55,997.8,983.2,977.95,975.35,978.8,963.1,978.95,983.2,1024.8,1014.0,1009.8,1004.1,990.35,1008.75,1016.45,1021.6,1028.05,1067.95,1069.7,1076.95,1092.05,1073.95,1091.4,1091.45,1100.45,1093.3,1088.15,1074.25,1092.05,1125.9,1123.2,1129.7,1106.55,1124.7,1127.35,1120.9,1090.7,1084.25,1061.8,1063.2,1054.1,1075.75,1088.2,1071.25,1061.25,1017.25,1035.05,1033.6,1023.75,1021.15,1020.65,1007.85,1032.8,1079.4,1067.8,1082.95,1071.8,1043.65,1016.55,1020.6,998.65,999.95,995.55,1022.65,985.65,1008.05,1022.25,1036.65,1045.6,1010.55,1011.05,1030.8,1031.2,1007.75,996.4,1007.05,1015.35,1046.4,1063.5,1066.1,1057.95,1071.4,1054.35,1065.65,1063.8,1058.7,1052.05,1062.95,1090.15,1067.45,1089.85,1076.25,1068.95,1068.3,1073.9,1053.55,1057.1,1057.65,1056.25,1074.3,1070.45,1073.45,1062.95,1056.05,1052.95,1058.4,1059.0,1060.45,1053.1,1053.5,1021.25,1010.15,1009.65,1014.55,1027.75,1016.05,1007.05,1000.1,993.6,987.9,983.25,972.6,979.1,976.9,
print('variance1=%f, variance2=%f' % (var1, var2))

# %%
x0 = X1
# Add 1 to shift the mean of the Gaussian distribution
x1 = X2

df =pd.DataFrame(dict(
    series=np.concatenate((["a"]*len(x0), ["b"]*len(x1))), 
    data  =np.concatenate((x0,x1))
))

px.histogram(df, x="data", color="series", barmode="overlay", nbins=10, histnorm='probability density')
# px.histogram(df, x="data", color="series", barmode="overlay")

# %%
print(' KLD = %+8.2e' % (sample_KLD(bins=10)))

# %%
X1, X2 = train_set, test_set[400:500]
mean1, mean2 = X1.mean(), X2.mean()
var1, var2 = X1.var(), X2.var()
print('mean1=%f, mean2=%f' % (mean1, mean2))
print('variance1=%f, variance2=%f' % (var1, var2))
# Out:
# mean1=973.087522, mean2=2002.174500
# variance1=28266.246848, variance2=5993.488475

# %%
x0 = X1
# Add 1 to shift the mean of the Gaussian distribution
x1 = X2

df =pd.DataFrame(dict(
    series=np.concatenate((["a"]*len(x0), ["b"]*len(x1))), 
    data  =np.concatenate((x0,x1))
))

px.histogram(df, x="data", color="series", barmode="overlay", nbins=10, histnorm='probability density')
# px.histogram(df, x="data", color="series", barmode="overlay")
# Out:
# <div>                            <div id="ab8068d3-f062-4299-bf42-b1deb3e4f35b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab8068d3-f062-4299-bf42-b1deb3e4f35b")) {                    Plotly.newPlot(                        "ab8068d3-f062-4299-bf42-b1deb3e4f35b",                        [{"alignmentgroup":"True","bingroup":"x","histnorm":"probability density","hovertemplate":"series=a<br>data=%{x}<br>probability density=%{y}<extra></extra>","legendgroup":"a","marker":{"color":"#636efa","opacity":0.5,"pattern":{"shape":""}},"name":"a","nbinsx":10,"offsetgroup":"a","orientation":"v","showlegend":true,"x":[1075.5,1070.7,1088.0,1106.05,1103.15,1081.5,1084.35,1088.6,1121.7,1110.75,1099.5,1085.0,1077.5,1054.05,1053.85,1042.05,1027.55,1037.15,1046.2,1045.4,1027.3,1033.95,1019.15,981.7,993.75,994.35,993.25,985.1,1015.15,1010.0,1017.75,1032.55,997.8,983.2,977.95,975.35,978.8,963.1,978.95,983.2,1024.8,1014.0,1009.8,1004.1,990.35,1008.75,1016.45,1021.6,1028.05,1067.95,1069.7,1076.95,1092.05,1073.95,1091.4,1091.45,1100.45,1093.3,1088.15,1074.25,1092.05,1125.9,1123.2,1129.7,1106.55,1124.7,1127.35,1120.9,1090.7,1084.25,1061.8,1063.2,1054.1,1075.75,1088.2,1071.25,1061.25,1017.25,1035.05,1033.6,1023.75,1021.15,1020.65,1007.85,1032.8,1079.4,1067.8,1082.95,1071.8,1043.65,1016.55,1020.6,998.65,999.95,995.55,1022.65,985.65,1008.05,1022.25,1036.65,1045.6,1010.55,1011.05,1030.8,1031.2,1007.75,996.4,1007.05,1015.35,1046.4,1063.5,1066.1,1057.95,1071.4,1054.35,1065.65,1063.8,1058.7,1052.05,1062.95,1090.15,1067.45,1089.85,1076.25,1068.95,1068.3,1073.9,1053.55,1057.1,1057.65,1056.25,1074.3,1070.45,1073.45,1062.95,1056.05,1052.95,1058.4,1059.0,1060.45,1053.1,1053.5,1021.25,1010.15,1009.65,1014.55,1027.75,1016.05,1007.05,1000.1,993.6,987.9,983.25,972.6,979.1,976.9,970.65,964.6,977.2,988.65,976.9,972.4,967.8,956.45,949.6,947.95,919.2,936.2,937.45,925.7,952.65,962.3,959.6,958.55,992.5,988.15,1013.9,1000.35,1027.35,1041.4,1035.15,1020.05,997.65,1001.65,1010.2,998.5,999.0,987.25,1007.9,1017.85,1023.85,1044.95,1039.15,1049.65,1069.2,1055.6,1073.05,1059.0,1040.35,1047.45,1044.4,1049.45,1081.65,1081.8,1090.35,1098.85,1092.75,1082.0,1096.25,1093.2,1074.85,1065.3,1105.05,1105.7,1111.85,1108.55,1102.2,1079.9,1061.85,1054.7,1030.5,1032.95,996.25,1012.25,995.6,996.05,979.5,962.35,998.4,985.6,988.8,1011.15,1005.9,1020.15,1030.75,1020.55,984.5,1023.9,1041.75,1055.25,1053.9,1056.85,1056.75,1073.15,1056.05,1059.4,1059.7,1055.25,1047.9,1048.6,1051.2,1058.7,1055.6,1077.1,1075.8,1085.6,1065.4,1033.45,1013.75,1030.8,1015.35,1001.5,997.9,994.85,980.15,969.85,986.8,971.6,958.5,942.7,913.0,919.3,895.5,921.3,943.9,920.0,929.05,915.25,914.3,899.65,909.95,914.8,941.7,944.15,953.95,935.55,956.35,984.85,995.65,964.2,966.25,964.25,988.85,977.4,982.2,977.05,984.95,993.85,984.75,992.05,1018.35,1037.25,1047.1,1030.85,993.0,990.3,999.65,1013.25,1010.3,1026.6,1025.7,1022.75,1032.5,1049.1,1036.4,1050.65,1047.65,1044.85,1041.9,1023.9,1005.3,1021.8,1020.95,1009.15,1011.65,1025.9,1040.6,1009.35,1001.15,986.1,972.4,983.75,964.75,943.9,947.65,949.95,955.05,955.05,959.3,950.75,955.45,945.5,948.0,945.0,920.65,901.85,915.5,923.2,909.4,915.75,906.0,933.85,945.45,938.85,951.85,946.8,951.05,934.6,937.75,958.25,949.2,954.0,944.5,925.6,911.35,900.55,887.55,868.75,833.25,848.65,845.8,870.5,871.4,871.55,871.1,885.25,898.5,861.95,868.4,845.95,852.9,870.7,854.85,853.3,847.75,865.45,867.55,873.2,867.6,879.45,876.2,860.85,873.35,882.85,871.5,860.85,837.35,827.95,830.85,837.3,825.05,812.35,792.0,780.65,765.3,765.3,772.75,772.2,760.9,759.15,755.0,741.2,732.55,757.0,765.25,761.3,753.5,719.4,755.05,782.6,805.45,788.85,821.5,833.5,852.45,825.75,806.3,810.25,825.4,836.3,825.65,821.55,851.8,837.6,786.35,770.6,759.2,797.2,797.2,807.7,808.35,788.2,771.6,767.0,802.9,829.25,827.0,8 ...

# %%
print(' KLD = %+8.2e' % (sample_KLD(bins=10)))
# Out:
# P [4.91359102e-04 1.51627993e-03 1.73633646e-03 1.86595880e-03
#  6.33039334e-04 2.26085476e-04 2.32114422e-04 1.53738124e-04
#  3.61736762e-05 9.04341905e-05]
# Q [0.00055532 0.00249896 0.00499792 0.00388727 0.00666389 0.00305428
#  0.00249896 0.00138831 0.00055532 0.00166597]
#  KLD = -7.35e-03

# %% [markdown]
# #### 2. Jensen Shannon Divergence

# %%
def JSdivergence(P, Q):
    """Compute the Jensen-Shannon divergence between two probability distributions.

    Input
    -----
    P, Q : array-like Probability distributions 
    """

    P = np.array(P)
    Q = np.array(Q)

    M = 0.5 * (P + Q)

    return 0.5 * (KLD(0.68*P, M) +KLD(0.68*Q, M))
